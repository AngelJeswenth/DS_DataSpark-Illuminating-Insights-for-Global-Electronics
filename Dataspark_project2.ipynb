# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
df1 = pd.read_csv(r"C:/Users/HP/OneDrive/Desktop/Data Spark/Customers .csv" , encoding = 'ISO-8859-1')

# %%
df1
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
#                    State Zip Code        Country      Continent    Birthday
# 0        South Australia     5523      Australia      Australia    7/3/1939
# 1      Western Australia     6522      Australia      Australia   9/27/1979
# 2               Victoria     3380      Australia      Australia   5/26/1947
# 3        South Australia     5223      Australia      Australia   9/17/1957
# 4               Victoria     3698      Australia      Australia  11/19/1965
# ...                  ...      ...            ...            ...         ...
# 15261              Texas    77017  United States  North America   3/25/1936
# 15262           Virginia    22101  United States  North America   2/16/1992
# 15263     North Carolina    28405  United States  North America   11/9/1937
# 15264         California    92501  United States  North America  10/12/1937
# 15265           Michigan    48302  United States  North America   8/18/1965
#
# [15266 rows x 10 columns]

# %%
df1.shape
# Out:
# (15266, 10)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15256 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  object
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.2+ MB

# %%
df1.isnull().sum()
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
df1[df1["State Code"].isnull()]
# Out:
#       CustomerKey  Gender                Name               City State Code  \
# 5304       729681  Female    Rossana Padovesi            Polvica        NaN
# 5316       732289    Male        Indro Piccio          Varcaturo        NaN
# 5372       742042    Male     Amaranto Loggia          Casaferro        NaN
# 5377       742886  Female       Edmonda Capon           Terzigno        NaN
# 5378       743343  Female        Ambra Sagese  Pomigliano D'Arco        NaN
# 5485       759705    Male    Callisto Lo Duca            Casilli        NaN
# 5525       765589    Male  Michelino Lucchesi       Pompei Scavi        NaN
# 5531       766410    Male   Adelmio Beneventi             Licola        NaN
# 5631       781667  Female          Ilda Manna             Napoli        NaN
# 5695       789177    Male   Calogero Folliero      Mariglianella        NaN
#
#        State Zip Code Country Continent    Birthday
# 5304  Napoli    80035   Italy    Europe   4/18/1981
# 5316  Napoli    80014   Italy    Europe   2/24/1949
# 5372  Napoli    80034   Italy    Europe   3/14/1936
# 5377  Napoli    80040   Italy    Europe    8/6/1963
# 5378  Napoli    80038   Italy    Europe    1/5/1961
# 5485  Napoli    80047   Italy    Europe   8/28/1976
# 5525  Napoli    80045   Italy    Europe  11/13/1947
# 5531  Napoli    80078   Italy    Europe   1/13/1940
# 5631  Napoli    80134   Italy    Europe    5/8/1977
# 5695  Napoli    80030   Italy    Europe    3/3/2000

# %%
df1["State Code"] = df1["State Code"].fillna("NA")

# %%
df1["Birthday"] = pd.to_datetime(df1["Birthday"])

# %%
 df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15266 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  object
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 1.2+ MB

# %%
df1.isnull().sum()
# Out:
# CustomerKey    0
# Gender         0
# Name           0
# City           0
# State Code     0
# State          0
# Zip Code       0
# Country        0
# Continent      0
# Birthday       0
# dtype: int64

# %%
df1
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
#                    State Zip Code        Country      Continent   Birthday
# 0        South Australia     5523      Australia      Australia 1939-07-03
# 1      Western Australia     6522      Australia      Australia 1979-09-27
# 2               Victoria     3380      Australia      Australia 1947-05-26
# 3        South Australia     5223      Australia      Australia 1957-09-17
# 4               Victoria     3698      Australia      Australia 1965-11-19
# ...                  ...      ...            ...            ...        ...
# 15261              Texas    77017  United States  North America 1936-03-25
# 15262           Virginia    22101  United States  North America 1992-02-16
# 15263     North Carolina    28405  United States  North America 1937-11-09
# 15264         California    92501  United States  North America 1937-10-12
# 15265           Michigan    48302  United States  North America 1965-08-18
#
# [15266 rows x 10 columns]

# %%
df2 = pd.read_csv(r"C:/Users/HP/OneDrive/Desktop/Data Spark/Data_Dictionary .csv")

# %%
df2
# Out:
#              Table           Field  \
# 0            Sales    Order Number
# 1            Sales       Line Item
# 2            Sales      Order Date
# 3            Sales   Delivery Date
# 4            Sales     CustomerKey
# 5            Sales        StoreKey
# 6            Sales      ProductKey
# 7            Sales        Quantity
# 8            Sales   Currency Code
# 9        Customers     CustomerKey
# 10       Customers          Gender
# 11       Customers            Name
# 12       Customers            City
# 13       Customers      State Code
# 14       Customers           State
# 15       Customers        Zip Code
# 16       Customers         Country
# 17       Customers       Continent
# 18       Customers        Birthday
# 19        Products      ProductKey
# 20        Products    Product Name
# 21        Products           Brand
# 22        Products           Color
# 23        Products   Unit Cost USD
# 24        Products  Unit Price USD
# 25        Products  SubcategoryKey
# 26        Products     Subcategory
# 27        Products     CategoryKey
# 28        Products        Category
# 29          Stores        StoreKey
# 30          Stores         Country
# 31          Stores           State
# 32          Stores   Square Meters
# 33          Stores       Open Date
# 34  Exchange Rates            Date
# 35  Exchange Rates        Currency
# 36  Exchange Rates        Exchange
#
#                                           Description
# 0                            Unique ID for each order
# 1   Identifies individual products purchased as pa...
# 2                           Date the order was placed
# 3                        Date the order was delivered
# 4   Unique key identifying which customer placed t...
# 5   Unique key identifying which store processed t...
# 6   Unique key identifying which product was purch...
# 7                           Number of items purchased
# 8                  Currency used to process the order
# 9                   Primary key to identify customers
# 10                                    Customer gender
# 11                                 Customer full name
# 12                                      Customer city
# 13                       Customer state (abbreviated)
# 14                              Customer state (full)
# 15                                  Customer zip code
# 16                                   Customer country
# 17                                 Customer continent
# 18                             Customer date of birth
# 19                   Primary key to identify products
# 20                                       Product name
# 21                                      Product brand
# 22                                      Product color
# 23                 Cost to produce the product in USD
# 24                          Product list price in USD
# 25              Key to identify product subcategories
# 26                           Product subcategory name
# 27                 Key to identify product categories
# 28                              Product category name
# 29                     Primary key to identify stores
# 30                                      Store country
# 31                                        Store state
# 32                   Store footprint in square meters
# 33                                    Store open date
# 34                                               Date
# 35                                      Currency code
# 36                      Exchange rate compared to USD

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Table        37 non-null     object
#  1   Field        37 non-null     object
#  2   Description  37 non-null     object
# dtypes: object(3)
# memory usage: 1020.0+ bytes

# %%
df2.isnull().sum()
# Out:
# Table          0
# Field          0
# Description    0
# dtype: int64

# %%
df3 = pd.read_csv(r"C:/Users/HP/OneDrive/Desktop/Data Spark/Exchange_Rates .csv")

# %%
df3
# Out:
#             Date Currency  Exchange
# 0       1/1/2015      USD    1.0000
# 1       1/1/2015      CAD    1.1583
# 2       1/1/2015      AUD    1.2214
# 3       1/1/2015      EUR    0.8237
# 4       1/1/2015      GBP    0.6415
# ...          ...      ...       ...
# 11210  2/20/2021      USD    1.0000
# 11211  2/20/2021      CAD    1.2610
# 11212  2/20/2021      AUD    1.2723
# 11213  2/20/2021      EUR    0.8238
# 11214  2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  object
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 263.0+ KB

# %%
df3.isnull().sum()
# Out:
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
df3["Date"] = pd.to_datetime(df3["Date"])
df3["Currency"] = df3["Currency"].astype(str)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  datetime64[ns]
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 263.0+ KB

# %%
df4 = pd.read_csv(r"C:/Users/HP/OneDrive/Desktop/Data Spark/Products .csv")

# %%
df4
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# 0     Silver        $6.62         $12.99              101
# 1       Blue        $6.62         $12.99              101
# 2      White        $7.40         $14.52              101
# 3     Silver       $11.00         $21.57              101
# 4        Red       $11.00         $21.57              101
# ...      ...           ...            ...             ...
# 2512     Red       $43.07        $129.99              505
# 2513   White       $43.07        $129.99              505
# 2514   White        $1.71          $3.35              505
# 2515   Black        $1.71          $3.35              505
# 2516  Silver        $1.71          $3.35              505
#
#                   Subcategory  CategoryKey     Category
# 0                     MP4&MP3            1        Audio
# 1                     MP4&MP3            1        Audio
# 2                     MP4&MP3            1        Audio
# 3                     MP4&MP3            1        Audio
# 4                     MP4&MP3            1        Audio
# ...                       ...          ...          ...
# 2512  Cell phones Accessories            5  Cell phones
# 2513  Cell phones Accessories            5  Cell phones
# 2514  Cell phones Accessories            5  Cell phones
# 2515  Cell phones Accessories            5  Cell phones
# 2516  Cell phones Accessories            5  Cell phones
#
# [2517 rows x 10 columns]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   object
#  5   Unit Price USD  2517 non-null   object
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 196.8+ KB

# %%
df4.isnull().sum()
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
 # df4["Subcategory"].value_counts()

# %%
df4["Unit Cost USD"] = df4["Unit Cost USD"].str.replace('$','').astype(str)
df4["Unit Price USD"] = df4["Unit Price USD"].str.replace('$','').astype(str)

# %%
df4
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# 0     Silver         6.62          12.99              101
# 1       Blue         6.62          12.99              101
# 2      White         7.40          14.52              101
# 3     Silver        11.00          21.57              101
# 4        Red        11.00          21.57              101
# ...      ...           ...            ...             ...
# 2512     Red        43.07         129.99              505
# 2513   White        43.07         129.99              505
# 2514   White         1.71           3.35              505
# 2515   Black         1.71           3.35              505
# 2516  Silver         1.71           3.35              505
#
#                   Subcategory  CategoryKey     Category
# 0                     MP4&MP3            1        Audio
# 1                     MP4&MP3            1        Audio
# 2                     MP4&MP3            1        Audio
# 3                     MP4&MP3            1        Audio
# 4                     MP4&MP3            1        Audio
# ...                       ...          ...          ...
# 2512  Cell phones Accessories            5  Cell phones
# 2513  Cell phones Accessories            5  Cell phones
# 2514  Cell phones Accessories            5  Cell phones
# 2515  Cell phones Accessories            5  Cell phones
# 2516  Cell phones Accessories            5  Cell phones
#
# [2517 rows x 10 columns]

# %%
df5 = pd.read_csv(r"C:/Users/HP/OneDrive/Desktop/Data Spark/Sales .csv")

# %%
df5
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# 1             0        1048         2           USD
# 2             0        2007         1           USD
# 3             0        1106         7           CAD
# 4             0         373         1           CAD
# ...         ...         ...       ...           ...
# 62879        43         632         3           USD
# 62880         0          98         4           EUR
# 62881         0        1613         2           CAD
# 62882         0        1717         2           CAD
# 62883         0         464         7           CAD
#
# [62884 rows x 9 columns]

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  object
#  3   Delivery Date  13165 non-null  object
#  4   CustomerKey    62884 non-null  int64
#  5   StoreKey       62884 non-null  int64
#  6   ProductKey     62884 non-null  int64
#  7   Quantity       62884 non-null  int64
#  8   Currency Code  62884 non-null  object
# dtypes: int64(6), object(3)
# memory usage: 4.3+ MB

# %%
df5.isnull().sum()
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
df5["Order Date"] = pd.to_datetime(df5["Order Date"])
df5["Delivery Date"] = pd.to_datetime(df5["Delivery Date"])
df5["Currency Code"] = df5["Currency Code"].astype(str)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  datetime64[ns]
#  3   Delivery Date  13165 non-null  datetime64[ns]
#  4   CustomerKey    62884 non-null  int64
#  5   StoreKey       62884 non-null  int64
#  6   ProductKey     62884 non-null  int64
#  7   Quantity       62884 non-null  int64
#  8   Currency Code  62884 non-null  object
# dtypes: datetime64[ns](2), int64(6), object(1)
# memory usage: 4.3+ MB

# %%
df5[df5["Delivery Date"].isnull()]
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01           NaT       265598
# 6            366004          1 2016-01-01           NaT      1107461
# 7            366004          2 2016-01-01           NaT      1107461
# 8            366005          1 2016-01-01           NaT       844003
# 9            366007          1 2016-01-01           NaT      2035771
# ...             ...        ...        ...           ...          ...
# 62867       2243025          1 2021-02-20           NaT      1909290
# 62868       2243025          2 2021-02-20           NaT      1909290
# 62869       2243026          1 2021-02-20           NaT      1737466
# 62872       2243028          1 2021-02-20           NaT      1728060
# 62879       2243030          1 2021-02-20           NaT      1216913
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# 6            38         163         6           GBP
# 7            38        1529         2           GBP
# 8            33         421         4           EUR
# 9            43        1617         1           USD
# ...         ...         ...       ...           ...
# 62867        49        1128         2           USD
# 62868        49        2511         2           USD
# 62869        49          58         6           USD
# 62872        66        1584         3           USD
# 62879        43         632         3           USD
#
# [49719 rows x 9 columns]

# %%
# df5['Delivery Date'] = df5['Delivery Date'].fillna(df5['Order Date'] + pd.Timedelta(days=3))
df5['Delivery Date'] = df5['Delivery Date'].fillna("Not Available")

# %%
df5
# Out:
#        Order Number  Line Item Order Date        Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01        Not Available       265598
# 1            366001          1 2016-01-01  2016-01-13 00:00:00      1269051
# 2            366001          2 2016-01-01  2016-01-13 00:00:00      1269051
# 3            366002          1 2016-01-01  2016-01-12 00:00:00       266019
# 4            366002          2 2016-01-01  2016-01-12 00:00:00       266019
# ...             ...        ...        ...                  ...          ...
# 62879       2243030          1 2021-02-20        Not Available      1216913
# 62880       2243031          1 2021-02-20  2021-02-24 00:00:00       511229
# 62881       2243032          1 2021-02-20  2021-02-23 00:00:00       331277
# 62882       2243032          2 2021-02-20  2021-02-23 00:00:00       331277
# 62883       2243032          3 2021-02-20  2021-02-23 00:00:00       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# 1             0        1048         2           USD
# 2             0        2007         1           USD
# 3             0        1106         7           CAD
# 4             0         373         1           CAD
# ...         ...         ...       ...           ...
# 62879        43         632         3           USD
# 62880         0          98         4           EUR
# 62881         0        1613         2           CAD
# 62882         0        1717         2           CAD
# 62883         0         464         7           CAD
#
# [62884 rows x 9 columns]

# %%
df6 = pd.read_csv(r"C:/Users/HP/OneDrive/Desktop/Data Spark/Stores .csv")

# %%
df6
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# 4   12/9/2015
# ..        ...
# 62   3/6/2008
# 63   1/1/2010
# 64   1/1/2012
# 65   1/1/2014
# 66   1/1/2010
#
# [67 rows x 5 columns]

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  66 non-null     float64
#  4   Open Date      67 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.7+ KB

# %%
df6.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64

# %%
df6 = df6.fillna(0)

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  67 non-null     float64
#  4   Open Date      67 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.7+ KB

# %%
df6
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            0.0
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# 4   12/9/2015
# ..        ...
# 62   3/6/2008
# 63   1/1/2010
# 64   1/1/2012
# 65   1/1/2014
# 66   1/1/2010
#
# [67 rows x 5 columns]

# %%
df6["Open Date"] = pd.to_datetime(df6["Open Date"])
df6["Country"] = df6["Country"].astype(str)
df6["State"] =df6["State"].astype(str)

# %%
df6
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            0.0
#
#     Open Date
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# 4  2015-12-09
# ..        ...
# 62 2008-03-06
# 63 2010-01-01
# 64 2012-01-01
# 65 2014-01-01
# 66 2010-01-01
#
# [67 rows x 5 columns]

# %% [markdown]
# Combining different Dataframe

# %%
# create Overall_sales

sal_cus = pd.merge(df5, df1, on="CustomerKey", how="inner")
# sal_cus

# %%
sal_cus_prod = pd.merge(sal_cus, df4, on="ProductKey", how="inner" )
# sal_cus_prod

# %%
 sal_cus_prod.isnull().sum()
# Out:
# Order Number      0
# Line Item         0
# Order Date        0
# Delivery Date     0
# CustomerKey       0
# StoreKey          0
# ProductKey        0
# Quantity          0
# Currency Code     0
# Gender            0
# Name              0
# City              0
# State Code        0
# State             0
# Zip Code          0
# Country           0
# Continent         0
# Birthday          0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
sal_cus_prod_ex = pd.merge(sal_cus_prod, df3, left_on = ["Order Date","Currency Code"],right_on= ["Date","Currency"], how="inner")
# sal_cus_prod_ex

# %%
sal_cus_prod_ex_sto = pd.merge(sal_cus_prod_ex, df6, on=["StoreKey","State","Country"], how="inner")
# sal_cus_prod_ex_sto

# %%
overall_sales = sal_cus_prod_ex_sto
overall_sales = overall_sales.drop(["Delivery Date"],axis=1)

# %%
overall_sales
# Out:
#       Order Number  Line Item Order Date  CustomerKey  StoreKey  ProductKey  \
# 0          1645005          2 2019-07-03      1715326        65        1627
# 1          1645005          1 2019-07-03      1715326        65        1618
# 2          1830029          1 2020-01-04      1306013        65        1418
# 3          1097002          1 2018-01-01      1267352        65        2051
# 4           783005          2 2017-02-21      1286602        65          59
# ...            ...        ...        ...          ...       ...         ...
# 6176        394004          2 2016-01-29       602720        16        1138
# 6177        394004          1 2016-01-29       602720        16        1417
# 6178        394004          3 2016-01-29       602720        16        1190
# 6179       1492019          1 2019-01-31       651347        18        1674
# 6180        367006          1 2016-01-02       693285        18        2445
#
#       Quantity Currency Code  Gender                Name  ... Unit Price USD  \
# 0            3           USD    Male   Jeffrey Rothermel  ...         17.99
# 1            1           USD    Male   Jeffrey Rothermel  ...         58.99
# 2            4           USD    Male           Don Young  ...        293.00
# 3            2           USD    Male  Reynaldo Champagne  ...        179.99
# 4            1           USD  Female     Frances Colbert  ...        156.00
# ...        ...           ...     ...                 ...  ...            ...
# 6176         1           EUR  Female       Carine Sirois  ...        391.90
# 6177         2           EUR  Female       Carine Sirois  ...        268.00
# 6178         2           EUR  Female       Carine Sirois  ...        165.00
# 6179         2           EUR  Female       Estelle Morin  ...          6.99
# 6180         3           EUR  Female      Solaine Lanoie  ...          4.99
#
#      SubcategoryKey          Subcategory CategoryKey  \
# 0               602            Movie DVD           6
# 1               602            Movie DVD           6
# 2               503  Touch Screen Phones           5
# 3               803           Microwaves           8
# 4               104        Recording Pen           1
# ...             ...                  ...         ...
# 6176            402  Digital SLR Cameras           4
# 6177            503  Touch Screen Phones           5
# 6178            405           Camcorders           4
# 6179            701          Boxed Games           7
# 6180            808                 Fans           8
#
#                            Category       Date Currency Exchange  \
# 0     Music, Movies and Audio Books 2019-07-03      USD   1.0000
# 1     Music, Movies and Audio Books 2019-07-03      USD   1.0000
# 2                       Cell phones 2020-01-04      USD   1.0000
# 3                   Home Appliances 2018-01-01      USD   1.0000
# 4                             Audio 2017-02-21      USD   1.0000
# ...                             ...        ...      ...      ...
# 6176         Cameras and camcorders 2016-01-29      EUR   0.9158
# 6177                    Cell phones 2016-01-29      EUR   0.9158
# 6178         Cameras and camcorders 2016-01-29      EUR   0.9158
# 6179                 Games and Toys 2019-01-31      EUR   0.8705
# 6180                Home Appliances 2016-01-02      EUR   0.9185
#
#      Square Meters  Open Date
# 0           1785.0 2012-01-01
# 1           1785.0 2012-01-01
# 2           1785.0 2012-01-01
# 3           1785.0 2012-01-01
# 4           1785.0 2012-01-01
# ...            ...        ...
# 6176         385.0 2010-06-03
# 6177         385.0 2010-06-03
# 6178         385.0 2010-06-03
# 6179         310.0 2012-08-08
# 6180         310.0 2012-08-08
#
# [6181 rows x 31 columns]

# %%
overall_sales.to_csv("C:/Users/HP/OneDrive/Desktop/Data Spark/overall_sales.csv")

# %% [markdown]
# Label Encoder

# %%
# !pip install seaborn
# !pip install matplotlib
# Out:
# Requirement already satisfied: seaborn in c:\users\hp\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\hp\anaconda3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\hp\anaconda3\lib\site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\hp\anaconda3\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\hp\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\roaming\python\python311\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
encoder = LabelEncoder()
def encode(df):
    for i in df.columns:
        if df[i].dtype == 'object':
            df[i] = encoder.fit_transform(df[i])

# %%
encode(overall_sales)

# %% [markdown]
# Outlier Detection

# %% [markdown]
# 1. iqr Range

# %%
def out_det():
    print(ll)
    print(ul)
    print(iqr)

# %%
df = overall_sales
col = ['CustomerKey', 'ProductKey', 'StoreKey', 'Order Number']
q1 = df[col].quantile(0.25)
q3 = df[col].quantile(0.75)
iqr = q3-q1
ll = q1-1.5*iqr
ul = q3+1.5*iqr

# %%
out_det()
# Out:
# CustomerKey    -1326580.0
# ProductKey        -1389.0
# StoreKey            -29.0
# Order Number     204026.0
# dtype: float64
# CustomerKey     3605116.0
# ProductKey         3475.0
# StoreKey            107.0
# Order Number    2755986.0
# dtype: float64
# CustomerKey     1232924.0
# ProductKey         1216.0
# StoreKey             34.0
# Order Number     637990.0
# dtype: float64

# %%
# Detect outliers
outliers = overall_sales[(overall_sales[col] < ll) | (overall_sales[col] > ul)]

# Print or analyze the outliers
print(f'Number of outliers: {len(outliers)}')
# outliers
# Out:
# Number of outliers: 6181

# %% [markdown]
# 2. using BoxPlot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming overall_sales is your DataFrame
# overall_sales = pd.read_csv('path_to_your_combined_data.csv')  # Uncomment and load your dataset

# Set a Seaborn style
sns.set(style="darkgrid")

# Create box plots for each column
plt.figure(figsize=(12, 8))

for i, column in enumerate(col, start=1):
    plt.subplot(2, 2, i)  # Create a 2x2 grid of subplots
    sns.boxplot(data=overall_sales, y=column, color="lightblue", fliersize=5, linewidth=1.5)
    plt.title(f'Box Plot for {column} with Outliers', fontsize=14, fontweight='bold')
    plt.ylabel(column, fontsize=12)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)

plt.tight_layout()  # Adjust layout to prevent clipping
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set a style using Seaborn for enhanced aesthetics
sns.set(style="darkgrid")

# Set the figure size for better readability
plt.figure(figsize=(12, 6))

# Create the box plot using Seaborn for better visuals
sns.boxplot(data=overall_sales[col], palette="Set2", fliersize=6, linewidth=2)

# Customize the plot
plt.title('Enhanced Box Plot for Overall Sales', fontsize=18, fontweight='bold')
plt.xlabel('Sales Attributes', fontsize=14)
plt.ylabel('Values', fontsize=14)
plt.xticks(fontsize=12)  # Adjust the font size of x-axis ticks
plt.yticks(fontsize=12)  # Adjust the font size of y-axis ticks

# Show the grid for better interpretation
plt.grid(True)

# Show the enhanced plot
plt.tight_layout()  # Adjust layout to prevent label clipping
plt.show()

# %% [markdown]
# Finding Reltionship between variables

# %%
overall_sales.corr()
# Out:
#                 Order Number  Line Item  Order Date  CustomerKey  StoreKey  \
# Order Number        1.000000   0.005260    1.000000     0.024958  0.023828
# Line Item           0.005260   1.000000    0.005259     0.002222 -0.000992
# Order Date          1.000000   0.005259    1.000000     0.024959  0.023829
# CustomerKey         0.024958   0.002222    0.024959     1.000000  0.908575
# StoreKey            0.023828  -0.000992    0.023829     0.908575  1.000000
# ProductKey         -0.001367   0.021525   -0.001367    -0.017986 -0.007702
# Quantity           -0.006477  -0.003823   -0.006477     0.001518 -0.000991
# Currency Code       0.020724   0.006671    0.020725     0.892860  0.921799
# Gender             -0.039155  -0.006157   -0.039156    -0.017043  0.002939
# Name               -0.041037  -0.008991   -0.041038     0.043844  0.032241
# City                0.022597  -0.008047    0.022598     0.087021  0.090880
# State Code          0.010801  -0.011558    0.010801    -0.331683 -0.173371
# State               0.000202  -0.014910    0.000203    -0.230190 -0.051287
# Zip Code           -0.003082   0.003464   -0.003081     0.275699  0.216001
# Country             0.024016   0.005663    0.024017     0.905304  0.935383
# Continent           0.025439   0.006598    0.025440     0.917210  0.932008
# Birthday           -0.008863   0.007019   -0.008862    -0.051526 -0.037494
# Product Name        0.035999  -0.020462    0.035998     0.013549  0.017148
# Brand               0.056054  -0.022495    0.056053     0.016516  0.018916
# Color               0.010925  -0.005374    0.010925    -0.011099 -0.011220
# Unit Cost USD      -0.029848   0.005784   -0.029848     0.005733  0.010848
# Unit Price USD      0.028524   0.016071    0.028523    -0.003211 -0.003335
# SubcategoryKey     -0.009698   0.017627   -0.009699    -0.019312 -0.010754
# Subcategory        -0.027493  -0.003624   -0.027492    -0.001257  0.009308
# CategoryKey        -0.009247   0.017550   -0.009247    -0.019130 -0.010610
# Category           -0.054109   0.001275   -0.054110    -0.020931 -0.012069
# Date                1.000000   0.005259    1.000000     0.024959  0.023829
# Currency            0.020724   0.006671    0.020725     0.892860  0.921799
# Exchange            0.034935  -0.005352    0.034934    -0.537438 -0.599831
# Square Meters      -0.013715   0.010338   -0.013714    -0.082408 -0.079113
# Open Date           0.067628  -0.009709    0.067628    -0.143152 -0.130159
#
#                 ProductKey  Quantity  Currency Code    Gender      Name  ...  \
# Order Number     -0.001367 -0.006477       0.020724 -0.039155 -0.041037  ...
# Line Item         0.021525 -0.003823       0.006671 -0.006157 -0.008991  ...
# Order Date       -0.001367 -0.006477       0.020725 -0.039156 -0.041038  ...
# CustomerKey      -0.017986  0.001518       0.892860 -0.017043  0.043844  ...
# StoreKey         -0.007702 -0.000991       0.921799  0.002939  0.032241  ...
# ProductKey        1.000000  0.007396      -0.004874  0.025124  0.002474  ...
# Quantity          0.007396  1.000000      -0.004587  0.003522  0.016672  ...
# Currency Code    -0.004874 -0.004587       1.000000  0.011175  0.068493  ...
# Gender            0.025124  0.003522       0.011175  1.000000  0.054422  ...
# Name              0.002474  0.016672       0.068493  0.054422  1.000000  ...
# City             -0.005109  0.015741       0.053961 -0.012100  0.020986  ...
# State Code        0.001880 -0.001546      -0.440897 -0.038069 -0.081978  ...
# State             0.000755 -0.000381      -0.395367 -0.022440 -0.077552  ...
# Zip Code          0.001465 -0.011854       0.271818  0.002640  0.018608  ...
# Country          -0.006134 -0.001345       0.992456  0.012031  0.061823  ...
# Continent        -0.005687 -0.002160       0.972783  0.011744  0.057900  ...
# Birthday          0.011919  0.019087      -0.043881 -0.043934  0.021590  ...
# Product Name     -0.081962 -0.009362       0.019226 -0.006124 -0.009550  ...
# Brand            -0.111470 -0.000982       0.022412 -0.001900 -0.010260  ...
# Color             0.047587  0.000628      -0.008749  0.005569  0.000036  ...
# Unit Cost USD    -0.063374 -0.005996       0.005855 -0.019880  0.010109  ...
# Unit Price USD    0.053061 -0.005321       0.002839  0.015200  0.006169  ...
# SubcategoryKey    0.934402  0.013397      -0.008742  0.023989  0.005817  ...
# Subcategory       0.100944 -0.002896       0.000014 -0.019993 -0.016292  ...
# CategoryKey       0.933155  0.013476      -0.008580  0.024087  0.005799  ...
# Category          0.374856  0.022802      -0.014209  0.005357  0.003040  ...
# Date             -0.001367 -0.006477       0.020725 -0.039156 -0.041038  ...
# Currency         -0.004874 -0.004587       1.000000  0.011175  0.068493  ...
# Exchange          0.000035  0.003732      -0.799859 -0.019421 -0.084722  ...
# Square Meters     0.002101  0.010284      -0.152826 -0.036166 -0.020097  ...
# Open Date        -0.011456  0.014617      -0.215121  0.002514 -0.031802  ...
#
#                 Unit Price USD  SubcategoryKey  Subcategory  CategoryKey  \
# Order Number          0.028524       -0.009698    -0.027493    -0.009247
# Line Item             0.016071        0.017627    -0.003624     0.017550
# Order Date            0.028523       -0.009699    -0.027492    -0.009247
# CustomerKey          -0.003211       -0.019312    -0.001257    -0.019130
# StoreKey             -0.003335       -0.010754     0.009308    -0.010610
# ProductKey            0.053061        0.934402     0.100944     0.933155
# Quantity             -0.005321        0.013397    -0.002896     0.013476
# Currency Code         0.002839       -0.008742     0.000014    -0.008580
# Gender                0.015200        0.023989    -0.019993     0.024087
# Name                  0.006169        0.005817    -0.016292     0.005799
# City                 -0.019433       -0.004700     0.010548    -0.004676
# State Code           -0.007932        0.006683     0.018826     0.006591
# State                -0.015576        0.004744     0.025704     0.004622
# Zip Code              0.006317       -0.003654    -0.024629    -0.003587
# Country               0.002271       -0.010738    -0.000692    -0.010573
# Continent             0.000243       -0.008468    -0.001275    -0.008309
# Birthday              0.005901        0.016330    -0.006705     0.016295
# Product Name         -0.010414       -0.073936     0.051756    -0.075454
# Brand                -0.010499       -0.077443     0.038638    -0.078065
# Color                 0.014856        0.048769    -0.070018     0.048464
# Unit Cost USD        -0.256434       -0.034867     0.117233    -0.034294
# Unit Price USD        1.000000        0.097459    -0.207848     0.097408
# SubcategoryKey        0.097459        1.000000     0.142884     0.999967
# Subcategory          -0.207848        0.142884     1.000000     0.144781
# CategoryKey           0.097408        0.999967     0.144781     1.000000
# Category             -0.011302        0.520182     0.370021     0.522271
# Date                  0.028523       -0.009699    -0.027492    -0.009247
# Currency              0.002839       -0.008742     0.000014    -0.008580
# Exchange             -0.013096        0.004827     0.000182     0.004690
# Square Meters        -0.016021        0.010081     0.006345     0.010166
# Open Date             0.021333       -0.014877    -0.022023    -0.015086
#
#                 Category      Date  Currency  Exchange  Square Meters  \
# Order Number   -0.054109  1.000000  0.020724  0.034935      -0.013715
# Line Item       0.001275  0.005259  0.006671 -0.005352       0.010338
# Order Date     -0.054110  1.000000  0.020725  0.034934      -0.013714
# CustomerKey    -0.020931  0.024959  0.892860 -0.537438      -0.082408
# StoreKey       -0.012069  0.023829  0.921799 -0.599831      -0.079113
# ProductKey      0.374856 -0.001367 -0.004874  0.000035       0.002101
# Quantity        0.022802 -0.006477 -0.004587  0.003732       0.010284
# Currency Code  -0.014209  0.020725  1.000000 -0.799859      -0.152826
# Gender          0.005357 -0.039156  0.011175 -0.019421      -0.036166
# Name            0.003040 -0.041038  0.068493 -0.084722      -0.020097
# City            0.007706  0.022598  0.053961  0.037146       0.087775
# State Code     -0.002976  0.010801 -0.440897  0.485150       0.288611
# State           0.005695  0.000203 -0.395367  0.543343       0.175374
# Zip Code       -0.020200 -0.003081  0.271818 -0.182276       0.058324
# Country        -0.013610  0.024017  0.992456 -0.775755      -0.138446
# Continent      -0.016312  0.025440  0.972783 -0.672533      -0.109915
# Birthday       -0.007865 -0.008862 -0.043881  0.022283      -0.021827
# Product Name   -0.165058  0.035998  0.019226 -0.018591       0.013320
# Brand          -0.162058  0.056053  0.022412 -0.022788       0.021576
# Color           0.038496  0.010925 -0.008749 -0.002521      -0.020475
# Unit Cost USD   0.146594 -0.029848  0.005855 -0.009670       0.004015
# Unit Price USD -0.011302  0.028523  0.002839 -0.013096      -0.016021
# SubcategoryKey  0.520182 -0.009699 -0.008742  0.004827       0.010081
# Subcategory     0.370021 -0.027492  0.000014  0.000182       0.006345
# CategoryKey     0.522271 -0.009247 -0.008580  0.004690       0.010166
# Category        1.000000 -0.054110 -0.014209  0.004306       0.009364
# Date           -0.054110  1.000000  0.020725  0.034934      -0.013714
# Currency       -0.014209  0.020725  1.000000 -0.799859      -0.152826
# Exchange        0.004306  0.034934 -0.799859  1.000000       0.293658
# Square Meters   0.009364 -0.013714 -0.152826  0.293658       1.000000
# Open Date      -0.012458  0.067628 -0.215121  0.238083      -0.231821
#
#                 Open Date
# Order Number     0.067628
# Line Item       -0.009709
# Order Date       0.067628
# CustomerKey     -0.143152
# StoreKey        -0.130159
# ProductKey      -0.011456
# Quantity         0.014617
# Currency Code   -0.215121
# Gender           0.002514
# Name            -0.031802
# City            -0.122290
# State Code       0.120197
# State            0.198071
# Zip Code        -0.273878
# Country         -0.197611
# Continent       -0.203296
# Birthday         0.105760
# Product Name    -0.024893
# Brand           -0.033819
# Color            0.017994
# Unit Cost USD   -0.011143
# Unit Price USD   0.021333
# SubcategoryKey  -0.014877
# Subcategory     -0.022023
# CategoryKey     -0.015086
# Category        -0.012458
# Date             0.067628
# Currency        -0.215121
# Exchange         0.238083
# Square Meters   -0.231821
# Open Date        1.000000
#
# [31 rows x 31 columns]

# %%
# target column
col = ['CustomerKey', 'ProductKey', 'StoreKey', 'Order Number']

# %%
overall_sales[col].corr()
# Out:
#               CustomerKey  ProductKey  StoreKey  Order Number
# CustomerKey      1.000000   -0.017986  0.908575      0.024958
# ProductKey      -0.017986    1.000000 -0.007702     -0.001367
# StoreKey         0.908575   -0.007702  1.000000      0.023828
# Order Number     0.024958   -0.001367  0.023828      1.000000

# %%
# Step 1: Select relevant columns for correlation
columns_to_correlate = ['CustomerKey', 'ProductKey', 'StoreKey', 'Order Number']
correlation_data = overall_sales[columns_to_correlate]

# Step 2: Calculate the correlation matrix
correlation_matrix = correlation_data.corr()

# Step 3: Visualize the heatmap
plt.figure(figsize=(10, 6))
heatmap = sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap for CustomerKey, ProductKey, StoreKey, and OrderNumber')
plt.show()

# %%
overall_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6181 entries, 0 to 6180
# Data columns (total 31 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order Number    6181 non-null   int64
#  1   Line Item       6181 non-null   int64
#  2   Order Date      6181 non-null   datetime64[ns]
#  3   CustomerKey     6181 non-null   int64
#  4   StoreKey        6181 non-null   int64
#  5   ProductKey      6181 non-null   int64
#  6   Quantity        6181 non-null   int64
#  7   Currency Code   6181 non-null   int32
#  8   Gender          6181 non-null   int32
#  9   Name            6181 non-null   int32
#  10  City            6181 non-null   int32
#  11  State Code      6181 non-null   int32
#  12  State           6181 non-null   int32
#  13  Zip Code        6181 non-null   int32
#  14  Country         6181 non-null   int32
#  15  Continent       6181 non-null   int32
#  16  Birthday        6181 non-null   datetime64[ns]
#  17  Product Name    6181 non-null   int32
#  18  Brand           6181 non-null   int32
#  19  Color           6181 non-null   int32
#  20  Unit Cost USD   6181 non-null   int32
#  21  Unit Price USD  6181 non-null   int32
#  22  SubcategoryKey  6181 non-null   int64
#  23  Subcategory     6181 non-null   int32
#  24  CategoryKey     6181 non-null   int64
#  25  Category        6181 non-null   int32
#  26  Date            6181 non-null   datetime64[ns]
#  27  Currency        6181 non-null   int32
#  28  Exchange        6181 non-null   float64
#  29  Square Meters   6181 non-null   float64
#  30  Open Date       6181 non-null   datetime64[ns]
# dtypes: datetime64[ns](4), float64(2), int32(17), int64(8)
# memory usage: 1.1 MB

# %% [raw]
# Connect to SQL

# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\hp\anaconda3\lib\site-packages (9.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector as mysql

# Establish the connection
myconnection = mysql.connect(
    host="localhost",       # Replace with your host
    user="root",            # Your MySQL username
    passwd="Charvi@1812",   # Your MySQL password
)

# %%
cursor = myconnection.cursor()

# %%
cursor.execute('''create table dataspark.Customers 
                    (CustomerKey INT,
                    Gender CHAR(10),
                    Name VARCHAR(30),
                    City VARCHAR(50),
                    State_Code CHAR(50),
                    State VARCHAR(35),
                    Zip_Code VARCHAR(30),
                    Country VARCHAR(50),
                    Continent VARCHAR(30),
                    Birthday DATE)''')
myconnection.commit()
print("Successfully created Customers Table")
# Out:
# Successfully created Customers Table

# %%
for i in range(len(df1)):
    cursor.execute(f"insert into dataspark.Customers value {tuple(df1.iloc[i])}")
    myconnection.commit()
print("All the Datas are successfully inserted into Customers Table")
# Out:
# All the Datas are successfully inserted into Customers Table

# %%
pd.read_sql_query('''select * from dataspark.Customers''',myconnection)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16896\3956219989.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query('''select * from dataspark.Customers''',myconnection)
#        CustomerKey  Gender               Name                 City State_Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female   Denisa Dux9aková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
#                    State Zip_Code        Country      Continent    Birthday
# 0        South Australia     5523      Australia      Australia  1939-07-03
# 1      Western Australia     6522      Australia      Australia  1979-09-27
# 2               Victoria     3380      Australia      Australia  1947-05-26
# 3        South Australia     5223      Australia      Australia  1957-09-17
# 4               Victoria     3698      Australia      Australia  1965-11-19
# ...                  ...      ...            ...            ...         ...
# 15261              Texas    77017  United States  North America  1936-03-25
# 15262           Virginia    22101  United States  North America  1992-02-16
# 15263     North Carolina    28405  United States  North America  1937-11-09
# 15264         California    92501  United States  North America  1937-10-12
# 15265           Michigan    48302  United States  North America  1965-08-18
#
# [15266 rows x 10 columns]

# %%
cursor.execute("""create table dataspark.Exchange_Rates(Date DATE,
                    Currency VARCHAR(10),
                    Exchange FLOAT) """)
myconnection.commit()
print("Successfully created Exchange_Rates Table")
# Out:
# Successfully created Exchange_Rates Table

# %%
for i in range(len(df3)):
    cursor.execute(f"insert into dataspark.Exchange_Rates value {tuple(df3.iloc[i])}")
    myconnection.commit()
print("All the Datas are successfully inserted into Exchange_Rates Table")
# Out:
# All the Datas are successfully inserted into Exchange_Rates Table

# %%
pd.read_sql_query('''select * from dataspark.Exchange_Rates''',myconnection)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16896\2238619007.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query('''select * from dataspark.Exchange_Rates''',myconnection)
#              Date Currency  Exchange
# 0      2015-01-01      USD    1.0000
# 1      2015-01-01      CAD    1.1583
# 2      2015-01-01      AUD    1.2214
# 3      2015-01-01      EUR    0.8237
# 4      2015-01-01      GBP    0.6415
# ...           ...      ...       ...
# 11210  2021-02-20      USD    1.0000
# 11211  2021-02-20      CAD    1.2610
# 11212  2021-02-20      AUD    1.2723
# 11213  2021-02-20      EUR    0.8238
# 11214  2021-02-20      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
cursor.execute("""create table dataspark.Products(ProductKey INT,
                    Product_Name  TEXT,
                    Brand   VARCHAR(50),
                    Color  VARCHAR(30),
                    Unit_Cost  VARCHAR(20),
                    Unit_Price  VARCHAR(20),
                    SubcategoryKey  VARCHAR(100),
                    Subcategory  VARCHAR(100),
                    CategoryKey  INT,
                    Category VARCHAR(50)) """)
myconnection.commit()
print("Successfully created Products Table")
# Out:
# Successfully created Products Table

# %%
for i in range(len(df4)):
    cursor.execute(f"insert into dataspark.Products value {tuple(df4.iloc[i])}")
    myconnection.commit()
print("All the Datas are successfully inserted into Products Table")
# Out:
# All the Datas are successfully inserted into Products Table

# %%
pd.read_sql_query('''select * from dataspark.Products''',myconnection)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16896\1054508819.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query('''select * from dataspark.Products''',myconnection)
#       ProductKey                                   Product_Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit_Cost Unit_Price SubcategoryKey              Subcategory  \
# 0     Silver     6.62      12.99             101                  MP4&MP3
# 1       Blue     6.62      12.99             101                  MP4&MP3
# 2      White     7.40      14.52             101                  MP4&MP3
# 3     Silver    11.00      21.57             101                  MP4&MP3
# 4        Red    11.00      21.57             101                  MP4&MP3
# ...      ...       ...        ...            ...                      ...
# 2512     Red    43.07     129.99             505  Cell phones Accessories
# 2513   White    43.07     129.99             505  Cell phones Accessories
# 2514   White     1.71       3.35             505  Cell phones Accessories
# 2515   Black     1.71       3.35             505  Cell phones Accessories
# 2516  Silver     1.71       3.35             505  Cell phones Accessories
#
#       CategoryKey     Category
# 0               1        Audio
# 1               1        Audio
# 2               1        Audio
# 3               1        Audio
# 4               1        Audio
# ...           ...          ...
# 2512            5  Cell phones
# 2513            5  Cell phones
# 2514            5  Cell phones
# 2515            5  Cell phones
# 2516            5  Cell phones
#
# [2517 rows x 10 columns]

# %%
cursor.execute("""create table dataspark.Sales(Order_Number  INT,
                    Line_Item  INT,
                    Order_Date  DATE,
                    Delivery_Date   VARCHAR(30),
                    CustomerKey  INT,
                    StoreKey   INT,
                    ProductKey  INT,
                    Quantity   INT,
                    Currency_Code VARCHAR(10)) """)
myconnection.commit()
print("Successfully created Sales Table")
# Out:
# Successfully created Sales Table

# %%
for i in range(len(df5)):
    cursor.execute(f"insert into dataspark.Sales value {tuple(df5.iloc[i])}")
    myconnection.commit()
print("All the Datas are successfully inserted into Sales Table")
# Out:
# All the Datas are successfully inserted into Sales Table

# %%
pd.read_sql_query('''select * from dataspark.Sales''',myconnection)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16896\2292342739.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query('''select * from dataspark.Sales''',myconnection)
#        Order_Number  Line_Item  Order_Date        Delivery_Date  CustomerKey  \
# 0            366000          1  2016-01-01        Not Available       265598
# 1            366001          1  2016-01-01  2016-01-13 00:00:00      1269051
# 2            366001          2  2016-01-01  2016-01-13 00:00:00      1269051
# 3            366002          1  2016-01-01  2016-01-12 00:00:00       266019
# 4            366002          2  2016-01-01  2016-01-12 00:00:00       266019
# ...             ...        ...         ...                  ...          ...
# 62879       2243030          1  2021-02-20        Not Available      1216913
# 62880       2243031          1  2021-02-20  2021-02-24 00:00:00       511229
# 62881       2243032          1  2021-02-20  2021-02-23 00:00:00       331277
# 62882       2243032          2  2021-02-20  2021-02-23 00:00:00       331277
# 62883       2243032          3  2021-02-20  2021-02-23 00:00:00       331277
#
#        StoreKey  ProductKey  Quantity Currency_Code
# 0            10        1304         1           CAD
# 1             0        1048         2           USD
# 2             0        2007         1           USD
# 3             0        1106         7           CAD
# 4             0         373         1           CAD
# ...         ...         ...       ...           ...
# 62879        43         632         3           USD
# 62880         0          98         4           EUR
# 62881         0        1613         2           CAD
# 62882         0        1717         2           CAD
# 62883         0         464         7           CAD
#
# [62884 rows x 9 columns]

# %%
cursor.execute("""create table dataspark.Stores(StoreKey  INT,
                        Country  VARCHAR(50),
                        State VARCHAR(50),
                        Square_Meters    FLOAT,
                        Open_Date DATE) """)
myconnection.commit()
print("Successfully created Stores Table")
# Out:
# Successfully created Stores Table

# %%
for i in range(len(df6)):
    cursor.execute(f"insert into dataspark.Stores value {tuple(df6.iloc[i])}")
    myconnection.commit()
print("All the Datas are successfully inserted into Stores Table")
# Out:
# All the Datas are successfully inserted into Stores Table

# %%
pd.read_sql_query('''select * from dataspark.Stores''',myconnection)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16896\3835759241.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query('''select * from dataspark.Stores''',myconnection)
#     StoreKey        Country                         State  Square_Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            0.0
#
#      Open_Date
# 0   2008-01-01
# 1   2008-01-12
# 2   2012-01-07
# 3   2010-01-01
# 4   2015-12-09
# ..         ...
# 62  2008-03-06
# 63  2010-01-01
# 64  2012-01-01
# 65  2014-01-01
# 66  2010-01-01
#
# [67 rows x 5 columns]

# %%
overall_sales_df = pd.read_csv("overall_sales.csv")
overall_sales_df = overall_sales_df.drop(columns='Unnamed: 0')

# %%
overall_sales_df
# Out:
#       Order Number  Line Item  Order Date  CustomerKey  StoreKey  ProductKey  \
# 0          1645005          2  2019-07-03      1715326        65        1627
# 1          1645005          1  2019-07-03      1715326        65        1618
# 2          1830029          1  2020-01-04      1306013        65        1418
# 3          1097002          1  2018-01-01      1267352        65        2051
# 4           783005          2  2017-02-21      1286602        65          59
# ...            ...        ...         ...          ...       ...         ...
# 6176        394004          2  2016-01-29       602720        16        1138
# 6177        394004          1  2016-01-29       602720        16        1417
# 6178        394004          3  2016-01-29       602720        16        1190
# 6179       1492019          1  2019-01-31       651347        18        1674
# 6180        367006          1  2016-01-02       693285        18        2445
#
#       Quantity Currency Code  Gender                Name  ... Unit Price USD  \
# 0            3           USD    Male   Jeffrey Rothermel  ...         17.99
# 1            1           USD    Male   Jeffrey Rothermel  ...         58.99
# 2            4           USD    Male           Don Young  ...        293.00
# 3            2           USD    Male  Reynaldo Champagne  ...        179.99
# 4            1           USD  Female     Frances Colbert  ...        156.00
# ...        ...           ...     ...                 ...  ...            ...
# 6176         1           EUR  Female       Carine Sirois  ...        391.90
# 6177         2           EUR  Female       Carine Sirois  ...        268.00
# 6178         2           EUR  Female       Carine Sirois  ...        165.00
# 6179         2           EUR  Female       Estelle Morin  ...          6.99
# 6180         3           EUR  Female      Solaine Lanoie  ...          4.99
#
#      SubcategoryKey          Subcategory CategoryKey  \
# 0               602            Movie DVD           6
# 1               602            Movie DVD           6
# 2               503  Touch Screen Phones           5
# 3               803           Microwaves           8
# 4               104        Recording Pen           1
# ...             ...                  ...         ...
# 6176            402  Digital SLR Cameras           4
# 6177            503  Touch Screen Phones           5
# 6178            405           Camcorders           4
# 6179            701          Boxed Games           7
# 6180            808                 Fans           8
#
#                            Category        Date Currency Exchange  \
# 0     Music, Movies and Audio Books  2019-07-03      USD   1.0000
# 1     Music, Movies and Audio Books  2019-07-03      USD   1.0000
# 2                       Cell phones  2020-01-04      USD   1.0000
# 3                   Home Appliances  2018-01-01      USD   1.0000
# 4                             Audio  2017-02-21      USD   1.0000
# ...                             ...         ...      ...      ...
# 6176         Cameras and camcorders  2016-01-29      EUR   0.9158
# 6177                    Cell phones  2016-01-29      EUR   0.9158
# 6178         Cameras and camcorders  2016-01-29      EUR   0.9158
# 6179                 Games and Toys  2019-01-31      EUR   0.8705
# 6180                Home Appliances  2016-01-02      EUR   0.9185
#
#      Square Meters   Open Date
# 0           1785.0  2012-01-01
# 1           1785.0  2012-01-01
# 2           1785.0  2012-01-01
# 3           1785.0  2012-01-01
# 4           1785.0  2012-01-01
# ...            ...         ...
# 6176         385.0  2010-06-03
# 6177         385.0  2010-06-03
# 6178         385.0  2010-06-03
# 6179         310.0  2012-08-08
# 6180         310.0  2012-08-08
#
# [6181 rows x 31 columns]

# %%
cursor.execute("""create table dataspark.Overall_Sales(OrderNumber INT,
                        Line_Item  INT,
                        Order_Date  DATE,
                        CustomerKey    INT,
                        StoreKey INT,
                        ProductKey INT,
                        Quantity INT,
                        Currency_Code VARCHAR(10),
                        Gender CHAR(10),
                        Name VARCHAR(50),
                        City VARCHAR(50),
                        State_Code CHAR(50),
                        State VARCHAR(35),
                        Zip_Code VARCHAR(30),
                        Country VARCHAR(50),
                        Continent VARCHAR(30),
                        Birthday DATE,
                        Product_Name TEXT,
                        Brand VARCHAR(50),
                        Color VARCHAR(30),
                        Unit_Cost_USD VARCHAR(20),
                        Unit_Price_USD VARCHAR(20),
                        SubcategoryKey VARCHAR(100),
                        Subcategory VARCHAR(100),
                        CategoryKey INT,
                        Category VARCHAR(50),
                        Date DATE,
                        Currency VARCHAR(10),
                        Exchange FLOAT,
                        Square_Meters FLOAT,
                        Open_Date DATE) """)
myconnection.commit()
print("Successfully created Overall_Sales Table")
# Out:
# Successfully created Overall_Sales Table

# %%
for i in range(len(overall_sales_df)):
    cursor.execute(f"insert into dataspark.Overall_Sales value {tuple(overall_sales_df.iloc[i])}")
    myconnection.commit()
print("All the Datas are successfully inserted into Overall_Sales Table")
# Out:
# All the Datas are successfully inserted into Overall_Sales Table

# %%
pd.read_sql_query('''select * from dataspark.Overall_Sales''',myconnection)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16896\3686633783.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query('''select * from dataspark.Overall_Sales''',myconnection)
#       OrderNumber  Line_Item  Order_Date  CustomerKey  StoreKey  ProductKey  \
# 0         1645005          2  2019-07-03      1715326        65        1627
# 1         1645005          1  2019-07-03      1715326        65        1618
# 2         1830029          1  2020-01-04      1306013        65        1418
# 3         1097002          1  2018-01-01      1267352        65        2051
# 4          783005          2  2017-02-21      1286602        65          59
# ...           ...        ...         ...          ...       ...         ...
# 6176       394004          2  2016-01-29       602720        16        1138
# 6177       394004          1  2016-01-29       602720        16        1417
# 6178       394004          3  2016-01-29       602720        16        1190
# 6179      1492019          1  2019-01-31       651347        18        1674
# 6180       367006          1  2016-01-02       693285        18        2445
#
#       Quantity Currency_Code  Gender                Name  ... Unit_Price_USD  \
# 0            3           USD    Male   Jeffrey Rothermel  ...         17.99
# 1            1           USD    Male   Jeffrey Rothermel  ...         58.99
# 2            4           USD    Male           Don Young  ...        293.00
# 3            2           USD    Male  Reynaldo Champagne  ...        179.99
# 4            1           USD  Female     Frances Colbert  ...        156.00
# ...        ...           ...     ...                 ...  ...            ...
# 6176         1           EUR  Female       Carine Sirois  ...        391.90
# 6177         2           EUR  Female       Carine Sirois  ...        268.00
# 6178         2           EUR  Female       Carine Sirois  ...        165.00
# 6179         2           EUR  Female       Estelle Morin  ...          6.99
# 6180         3           EUR  Female      Solaine Lanoie  ...          4.99
#
#      SubcategoryKey          Subcategory CategoryKey  \
# 0               602            Movie DVD           6
# 1               602            Movie DVD           6
# 2               503  Touch Screen Phones           5
# 3               803           Microwaves           8
# 4               104        Recording Pen           1
# ...             ...                  ...         ...
# 6176            402  Digital SLR Cameras           4
# 6177            503  Touch Screen Phones           5
# 6178            405           Camcorders           4
# 6179            701          Boxed Games           7
# 6180            808                 Fans           8
#
#                            Category        Date Currency Exchange  \
# 0     Music, Movies and Audio Books  2019-07-03      USD   1.0000
# 1     Music, Movies and Audio Books  2019-07-03      USD   1.0000
# 2                       Cell phones  2020-01-04      USD   1.0000
# 3                   Home Appliances  2018-01-01      USD   1.0000
# 4                             Audio  2017-02-21      USD   1.0000
# ...                             ...         ...      ...      ...
# 6176         Cameras and camcorders  2016-01-29      EUR   0.9158
# 6177                    Cell phones  2016-01-29      EUR   0.9158
# 6178         Cameras and camcorders  2016-01-29      EUR   0.9158
# 6179                 Games and Toys  2019-01-31      EUR   0.8705
# 6180                Home Appliances  2016-01-02      EUR   0.9185
#
#      Square_Meters   Open_Date
# 0           1785.0  2012-01-01
# 1           1785.0  2012-01-01
# 2           1785.0  2012-01-01
# 3           1785.0  2012-01-01
# 4           1785.0  2012-01-01
# ...            ...         ...
# 6176         385.0  2010-06-03
# 6177         385.0  2010-06-03
# 6178         385.0  2010-06-03
# 6179         310.0  2012-08-08
# 6180         310.0  2012-08-08
#
# [6181 rows x 31 columns]
